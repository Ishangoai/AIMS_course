# %%
import os

import google.generativeai as genai

key = os.environ.get('GOOGLE_API_KEY')
# Set up API authentication
genai.configure(api_key=key)

model = genai.GenerativeModel("models/gemini-2.0-flash-lite")

response = model.generate_content("Explain quantum states in simple terms for a high school student.")

print(response.text)
# Out:
# Imagine you have a light switch. It can only be in one of two states: on or off. Now, imagine a tiny, tiny light switch, much smaller than anything you can see. This light switch is a simplified example of a quantum state.
#
# **What is a Quantum State?**
#
# Instead of just being "on" or "off," a quantum object, like an electron or a photon (light particle), can exist in a "superposition" of states. Think of it like this:
#
# *   **Classical (Regular) World:** The light switch is either *on* or *off*.
# *   **Quantum World:** The tiny light switch is *both on and off at the same time* until you look at it or measure it.  It's like a blurry mix of possibilities.
#
# **Key Ideas:**
#
# *   **Superposition:**  The ability to be in multiple states simultaneously. This is the heart of quantum mechanics and what makes it so weird.
# *   **Measurement:**  When you try to "look" or measure the state of the quantum object, the superposition "collapses," and it chooses one specific state (like the light switch finally flipping to on or off).
# *   **Probability:** You can't predict *exactly* what state the object will be in after a measurement, only the *probability* of each possible outcome.  For example, maybe there's a 60% chance it will be "on" and a 40% chance it will be "off."
# *   **Wave-Particle Duality:** Quantum objects can sometimes act like waves and sometimes like particles, depending on how they're observed. This is closely related to the idea of superposition.
#
# **Examples:**
#
# *   **Electron Spin:** Electrons have a property called "spin," which is like a tiny internal magnetic field. An electron can have spin "up" or spin "down." In a superposition, it's both up and down at the same time until you measure it.
# *   **Photon Polarization:** Light waves can be polarized, meaning the waves oscillate in a specific direction (think of the slits in polarized sunglasses). A photon's polarization can be horizontal, vertical, or a combination of both in superposition until measured.
#
# **Why is this important?**
#
# *   **Quantum Computing:** Uses superposition and other quantum principles to perform calculations much faster than regular computers for specific tasks.
# *   **Quantum Cryptography:**  Creates super-secure communication methods.
# *   **New Materials Science:** Helps us understand and design new materials with amazing properties.
#
# **Analogy:**
#
# Think of a coin spinning in the air.  Before it lands, it's neither heads nor tails, it's a superposition of both.  Only when it lands and you "measure" it (look at it) does it become definitively heads or tails.
#
# **Important Note:** Quantum mechanics is complex, and these are simplified explanations. Scientists are still grappling with the full implications of quantum states. But hopefully, this gives you a basic understanding of this fascinating concept!
